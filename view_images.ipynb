# %%
from IPython.display import Image

# %%
Image(filename='plots/epochs/compression/mnist_sgd_drop.png')

# %%
Image(filename='plots/epochs/mnist_sgd_weight_decay.png')

# %%
Image(filename='plots/epochs/mnist_sgd_weight_decay.png')

# %%
Image(filename='plots/epochs/mnist_rmsprop_drop.png')

# %%
Image(filename='plots/epochs/mnist_rmsprop_weight_decay.png')

# %%
Image(filename='plots/layers/compression/mnist_sgd_drop.png')

# %%
Image(filename='plots/layers/compression/mnist_sgd_weight_decay.png')

# %%
Image(filename='plots/layers/compression_aligned/mnist_sgd_drop.png')

# %%
Image(filename='plots/layers/compression_aligned/mnist_sgd_weight_decay.png')

# %%
Image(filename='plots/layers/compression_aligned_ratio/mnist_sgd_drop.png')

# %%
Image(filename='plots/layers/compression_aligned_ratio/mnist_sgd_weight_decay.png')

# %% [markdown]
# CIFAR 10

# %%
Image(filename='plots/epochs/cifar10_sgd_drop.png')

# %%
Image(filename='plots/epochs/cifar10_sgd_weight_decay.png')

# %%
Image(filename='plots/epochs/cifar10_rmsprop_drop.png')

# %%
Image(filename='plots/epochs/cifar10_rmsprop_weight_decay.png')

# %%
Image(filename='plots/layers/compression/cifar10_sgd_drop.png')

# %%
Image(filename='plots/layers/compression/cifar10_rmsprop_drop.png')

# %%
Image(filename='plots/layers/compression/cifar10_sgd_weight_decay.png')

# %%
Image(filename='plots/layers/compression/cifar10_rmsprop_weight_decay.png')

# %%
Image(filename='plots/layers/compression_aligned/cifar10_sgd_drop.png')

# %%
Image(filename='plots/layers/compression_aligned/cifar10_rmsprop_drop.png')

# %%
Image(filename='plots/layers/compression_aligned/cifar10_sgd_weight_decay.png')

# %%
Image(filename='plots/layers/compression_aligned/cifar10_rmsprop_weight_decay.png')

# %%
# Image(filename='plots/layers/compression_aligned_ratio/cifar10_sgd_drop.png')

# %%
Image(filename='plots/epochs/compression/cifar10_opt_comp.png')

# %%
Image(filename='plots/epochs/accuracy/mnist_opt_comp.png')

# %%
Image(filename='plots/epochs/accuracy/cifar10_opt_comp.png')

# %%
Image(filename='plots/epochs/loss/mnist_opt_comp.png')

# %%
Image(filename='plots/epochs/loss/cifar10_opt_comp.png')

# %%
Image(filename='plots/epochs/loss/cifar10_opt_comp.png')
